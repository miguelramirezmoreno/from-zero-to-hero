# %%
x = np.linspace(-20, 20, 100)
z = 1/(1 + np.exp(-x))
  
plt.plot(x, z)
plt.xlabel("x value")
plt.ylabel("Sigmoid(X)") 
plt.show()



import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# Generate 'random' data
np.random.seed(0)
X = 55 * np.random.randn(100) + 70  # Array of 100 values with mean = 1.5, stddev = 2.5
res = 0.8 * np.random.randn(100)       # Generate 100 residual terms
y = 2 + 300 * X + res                  # Actual values of Y

# Create pandas dataframe to store our X and y values
df = pd.DataFrame(
    {'Area (sq meters)': X,
     'Cost of the house (thousands $)': y}
)

# Show the first five rows of our dataframe
df.head()
list1 = [167, 92, 123, 193, 172]
X = np.array(list1)

list2 = [356, 162, 243, 435, 398]
Y = np.array(list2)


df = pd.DataFrame(
    {'Area of the property (square meters)': X,
     'Cost of the property (thousand dollars)': Y}
)

# Show the first five rows of our dataframe
df.head()


alpha = 6
beta = 3

ypred = 7 + 2* X

plt.figure(figsize=(4, 4))
plt.plot(X, ypred)     # regression line
plt.plot(X, Y, 'ro')   # scatter plot showing actual data
plt.title('Predicting the housing market of burlington, Vermont')
plt.xlabel('Area of the house (square meters)')
plt.ylabel('House cost (thousands of dollars)')

plt.show()

print(6 +2*150)
